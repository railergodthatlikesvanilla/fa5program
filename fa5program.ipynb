# %% [markdown]
# <a href="https://colab.research.google.com/github/railergodthatlikesvanilla/fa5program/blob/main/fa5program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#function
def get_sum(a,b):
  return a + b

#main
num1 = int(input("Enter the price of the item: "))
num2 = int(input("Enter the amount of it bought: "))
print("The total price is: ", (num1*num2))
# Out:
# Enter the price of the item: 6
# Enter the amount of it bought: 565
# The total price is:  3390
